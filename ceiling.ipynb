# %% [raw]
# ---
# title: "Die Saaldecke der Renaissance von Balthasar Katzenberger "
# jupyter: python3
# code-fold: true
# execute:
#   echo: false
#   output: asis
# ---

# %%
import sparqlQueries as sq
sq.get_text("Q229")
sq.get_img("Q229")
# Out:
# Wikibase link: [https://computational-publishing-service.wikibase.cloud/entity/Q229](https://computational-publishing-service.wikibase.cloud/entity/Q229)
#
# Kurator: Seeger, Ulrike
#
# ...

# %% [markdown]
# <hr>
